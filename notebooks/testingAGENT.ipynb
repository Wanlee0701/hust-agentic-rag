# %%
from src.agent import StudentRegulationAgent
agent = StudentRegulationAgent()
# Out:
# ❌ Failed to initialize LLM: name 'Ollama' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from src.agent import StudentRegulationAgent
# ----> 2 agent = StudentRegulationAgent()
#       3
#
# File c:\Users\PC\Desktop\ĐATN\src\agent\orchestrator.py:62, in StudentRegulationAgent.__init__(self, config_path)
#      59 self.tools = None
#      60 self.agent_executor = None
# ---> 62 self._initialize()
#
# File c:\Users\PC\Desktop\ĐATN\src\agent\orchestrator.py:80, in StudentRegulationAgent._initialize(self)
#      77 logger.info("🚀 Initializing StudentRegulationAgent...")
#      79 # 1. Khởi tạo LLM
# ---> 80 self._initialize_llm()
#      82 # 2. Khởi tạo Vector Database
#      83 self._initialize_vector_db()
#
# File c:\Users\PC\Desktop\ĐATN\src\agent\orchestrator.py:98, in StudentRegulationAgent._initialize_llm(self)
# ...

# %%
query = "Em có thể giải thích cho em về quy định học vụ của trường được không?"

# %%
result = agent.answer_question(query)
print(result)
print("\n---\n")
print("Conversation History:")
print(result['conversation_history'])
print("\n---\n")
print("Tool Usage History:")
print(result['tool_usage_history'])
print("\n---\n")
print("Agent's Thought Process:")
print(result['thought_process'])
print("\n---\n")
print(f"Confidence Score: {result['confidence_score']}")
print(f"Source Documents: {result['source_documents']}")
